# %% [markdown]
# **Hand Written Digits Classification**

# %% [markdown]
# **Load data from kagglehub**

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("olafkrastovski/handwritten-digits-0-9")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/olafkrastovski/handwritten-digits-0-9/2.archive...
# 100%|██████████| 66.7M/66.7M [00:00<00:00, 136MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/olafkrastovski/handwritten-digits-0-9/versions/2

# %% [markdown]
# **List all sub directories**

# %%
import os
print(os.listdir(path))
# Out:
# ['9', '1', '7', '5', '3', '0', '8', '4', '6', '2']

# %% [markdown]
# **Display 5 images in each folder**

# %%
import matplotlib.pyplot as plt
from PIL import Image #Python image library

plt.figure(figsize=(12,10))
i = 1
for class_name in os.listdir(path): # looping through all folders
  class_path = os.path.join(path,class_name) # add main path to each folder
  if os.path.isdir(class_path): # if folder exists
    images =os.listdir(class_path)[:5] #  taking 5 images in each folder

    for img in images:
      img_path = os.path.join(class_path,img)
      img = Image.open(img_path)

      plt.subplot(10,5,i)
      plt.imshow(img)
      plt.title(class_name)
      plt.axis('off')

      i+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# **count the number of images in each folder**

# %%
for x in os.listdir(path):
  class_path = os.path.join(path,x)
  count = len(os.listdir(class_path))
  print(x ,'-->',count)
# Out:
# 9 --> 2016
# 1 --> 2241
# 7 --> 2116
# 5 --> 2126
# 3 --> 2202
# 0 --> 2236
# 8 --> 2085
# 4 --> 2179
# 6 --> 2121
# 2 --> 2233

# %% [markdown]
# **Create dataframe with image path and labels**

# %%
import pandas as pd
df =[]
for label in os.listdir(path):
  class_path = os.path.join(path,label)
  if os.path.isdir(class_path):
    for img in os.listdir(class_path):
      img_path = os.path.join(class_path,img)
      df.append([img_path,label])
data = pd.DataFrame(df,columns=['img_path','label'])

# %%
data
# Out:
#                                                 img_path label
# 0      /root/.cache/kagglehub/datasets/olafkrastovski...     9
# 1      /root/.cache/kagglehub/datasets/olafkrastovski...     9
# 2      /root/.cache/kagglehub/datasets/olafkrastovski...     9
# 3      /root/.cache/kagglehub/datasets/olafkrastovski...     9
# 4      /root/.cache/kagglehub/datasets/olafkrastovski...     9
# ...                                                  ...   ...
# 21550  /root/.cache/kagglehub/datasets/olafkrastovski...     2
# 21551  /root/.cache/kagglehub/datasets/olafkrastovski...     2
# 21552  /root/.cache/kagglehub/datasets/olafkrastovski...     2
# 21553  /root/.cache/kagglehub/datasets/olafkrastovski...     2
# 21554  /root/.cache/kagglehub/datasets/olafkrastovski...     2
#
# [21555 rows x 2 columns]

# %% [markdown]
# **Shuffle data**

# %%
data = data.sample(frac=1,random_state=42).reset_index()
data
# Out:
#        index                                           img_path label
# 0       8645  /root/.cache/kagglehub/datasets/olafkrastovski...     3
# 1      12353  /root/.cache/kagglehub/datasets/olafkrastovski...     0
# 2       3261  /root/.cache/kagglehub/datasets/olafkrastovski...     1
# 3      11187  /root/.cache/kagglehub/datasets/olafkrastovski...     0
# 4      19142  /root/.cache/kagglehub/datasets/olafkrastovski...     6
# ...      ...                                                ...   ...
# 21550  11284  /root/.cache/kagglehub/datasets/olafkrastovski...     0
# 21551  11964  /root/.cache/kagglehub/datasets/olafkrastovski...     0
# 21552   5390  /root/.cache/kagglehub/datasets/olafkrastovski...     7
# 21553    860  /root/.cache/kagglehub/datasets/olafkrastovski...     9
# 21554  15795  /root/.cache/kagglehub/datasets/olafkrastovski...     4
#
# [21555 rows x 3 columns]

# %% [markdown]
# **find height and width of an image**

# %%
img_path = data['img_path'][0]
img = Image.open(img_path)
height,width = img.size
print('height: ',height,'width: ',width)
# Out:
# height:  90 width:  140

# %% [markdown]
# **Split data for training,validation and testing**

# %%
# images are huge
# Validation : We will be training deep learning model with images in batches
# After learning every batch model is evaluated we call that process as validation
# 70% for training
# 15% for validation
# 15% for testing
train_size =int(0.7*len(data))
val_size = int(0.15 * len(data))
test_size = int(0.15*len(data))
print("train_size-->",train_size)
print("val_size-->",val_size)
print("test_size-->",test_size)

train_data = data.iloc[:train_size] # data.iloc[:15088]
val_data =data.iloc[train_size:train_size+val_size]#data.iloc[15088:15088+3233]
test_data = data.iloc[train_size+val_size:] # data.iloc[15088+3233:]

print('train_data',len(train_data))
print('val_data',len(val_data))
print('test_data',len(test_data))
# Out:
# train_size--> 15088
# val_size--> 3233
# test_size--> 3233
# train_data 15088
# val_data 3233
# test_data 3234

# %% [markdown]
# **Image Preprocessing**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
batch_size=32
img_height=128
img_width = 128

# %%
data_generator = ImageDataGenerator(
    rescale=1.0/255, # pixel range from 0-255 converted into 0 to 1
    rotation_range=40 ,# rotates an image upto +_40 degree
    width_shift_range=0.2, #moves an image to right and left by 20%
    height_shift_range=0.2 , #moves image up and down by 20%
    shear_range =0.2 , # slant image in sideways,
    zoom_range=0.2,
    horizontal_flip = True, # flips images to left or right
    fill_mode ='nearest') # gaps in image is filled with nearest pixels.

# %%
train_generator = data_generator.flow_from_dataframe(
    dataframe = train_data,
    x_col = 'img_path',
    y_col ='label',
    target_size=(img_height,img_width),
    batch_size =batch_size,
    class_mode ='categorical',
    shuffle=True,seed=42)
# Out:
# Found 15088 validated image filenames belonging to 10 classes.

# %%
test_generator = data_generator.flow_from_dataframe(
    dataframe=test_data,
    x_col='img_path',
    y_col = 'label',
    target_size=(img_height,img_width),
    batch_size =batch_size,
    class_mode ='categorical',
    shuffle =True,seed=42
)
# Out:
# Found 3234 validated image filenames belonging to 10 classes.

# %%
val_generator = data_generator.flow_from_dataframe(
    dataframe=val_data,
    x_col='img_path',
    y_col = 'label',
    target_size=(img_height,img_width),
    batch_size =batch_size,
    class_mode ='categorical',
    shuffle =True,seed=42
)
# Out:
# Found 3233 validated image filenames belonging to 10 classes.

# %%
for image_batch,labels_batch in train_generator:
  print(f"Train shape: {image_batch.shape} (Batches={len(train_generator)})")
  break

for image_batch,labels_batch in test_generator:
  print(f"Test shape: {image_batch.shape} (Batches={len(test_generator)})")
  break

for image_batch,labels_batch in val_generator:
  print(f"val shape: {image_batch.shape} (Batches={len(val_generator)})")
  break
# Out:
# Train shape: (32, 128, 128, 3) (Batches=472)
# Test shape: (32, 128, 128, 3) (Batches=102)
# val shape: (32, 128, 128, 3) (Batches=102)

# %% [markdown]
# **CNN Model**

# %%
from tensorflow.keras import layers,models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy

# %%
# cnn model
n_classes = 10
cnn_model = models.Sequential([
    layers.Input(shape=(128,128,3)),
    layers.Conv2D(32,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(n_classes,activation='softmax')
])

# %%
cnn_model.compile(loss=categorical_crossentropy,optimizer=Adam(),metrics=['accuracy'])

# %%
cnn = cnn_model.fit(train_generator,epochs =5,validation_data=val_generator,verbose=1)
# Out:
# Epoch 1/5
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 456s 960ms/step - accuracy: 0.1296 - loss: 2.2824 - val_accuracy: 0.1689 - val_loss: 2.2341
# Epoch 2/5
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 449s 951ms/step - accuracy: 0.2397 - loss: 2.0736 - val_accuracy: 0.3483 - val_loss: 1.8070
# Epoch 3/5
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 457s 969ms/step - accuracy: 0.3842 - loss: 1.7297 - val_accuracy: 0.4371 - val_loss: 1.5894
# Epoch 4/5
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 446s 946ms/step - accuracy: 0.4706 - loss: 1.4880 - val_accuracy: 0.5258 - val_loss: 1.3693
# Epoch 5/5
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 444s 940ms/step - accuracy: 0.5471 - loss: 1.2929 - val_accuracy: 0.5861 - val_loss: 1.2000

# %% [markdown]
# **Evaluate the model**

# %%
train_loss, train_accuracy = cnn_model.evaluate(train_generator, verbose=1)
print(f'Training accuracy: {train_accuracy:.4f}')

# Evaluate on the test data
test_loss, test_accuracy = cnn_model.evaluate(test_generator, verbose=1)
print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 173s 367ms/step - accuracy: 0.5736 - loss: 1.2246
# Training accuracy: 0.5736
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 39s 375ms/step - accuracy: 0.5894 - loss: 1.2157
# Test accuracy: 0.5894

# %%
cnn_model.save("cnn_model.h5")

# %%
# Retrieve metrics from the training history
acc = cnn.history['accuracy']
val_acc = cnn.history['val_accuracy']
loss = cnn.history['loss']
val_loss = cnn.history['val_loss']

epochs_range = range(1, len(acc) + 1)

# Plot accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy for CNN')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss for CNN')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img_path = "three.jpg"

# Load image
img = image.load_img(img_path, target_size=(128, 128))  # same as training

# Convert to array
img_array = image.img_to_array(img)

# Normalize
img_array = img_array / 255.0

# Add batch dimension
img_array = np.expand_dims(img_array, axis=0)

# %% [markdown]
# **Predictions**

# %%
prediction = cnn_model.predict(img_array)
prediction
